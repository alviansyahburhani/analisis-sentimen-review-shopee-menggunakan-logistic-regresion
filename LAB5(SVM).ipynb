# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from Sastrawi.StopWordRemover import StopWordRemover
from Sastrawi.Stemmer import Stemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Inisialisasi StopWordRemover dan Stemmer
stopword_remover = StopWordRemoverFactory().create_stop_word_remover()
stemmer = StemmerFactory().create_stemmer()

def preprocess_text(text):
    # Menghapus stopword
    text_no_stopwords = stopword_remover.remove(text)
    # Melakukan stemming
    text_stemmed = stemmer.stem(text_no_stopwords)
    return text_stemmed

# %%
data = pd.read_excel('data_riviews_news.xlsx')
data
# Out:
#                                                 RIVIEW    LABEL
# 0    Baju ini sangat nyaman dipakai bahan yang digu...  Positif
# 1    Jaket ini sangat stylish dan hangat Saya sanga...  Positif
# 2    Pengiriman cepat dan baju datang dalam kondisi...  Positif
# 3    Bahan baju ini sangat lembut dan tidak panas d...  Positif
# 4    Jaket ini sesuai dengan deskripsi kualitasnya ...  Positif
# ..                                                 ...      ...
# 445  Jaket ini cepat sekali rusak setelah beberapa ...  Negatif
# 446  Baju ini tidak sesuai dengan gambar di website...  Negatif
# 447  Jaket ini terlalu tipis dan tidak hangat sama ...  Negatif
# 448    Baju ini sangat kasar dan tidak nyaman di kulit  Negatif
# 449      Jaket ini tidak tahan air sangat mengecewakan  Negatif
#
# [450 rows x 2 columns]

# %%
data['RIVIEW'] = data['RIVIEW'].apply(preprocess_text)

# %%
# Ubah label sentimen menjadi angka
sentiment_mapping = {'Positif': 1, 'Negatif': 2, 'Netral': 0}
data['LABEL'] = data['LABEL'].map(sentiment_mapping)

# %%
texts =data['RIVIEW']
sentiments = data ['LABEL']

X_train,X_test,y_train,y_test =train_test_split(texts,sentiments, test_size=0.3, random_state=42)

# %%
# Membuat vektor fitur dari data teks
Vectorizer = CountVectorizer()

X_train_counts = Vectorizer.fit_transform(X_train)
X_test_counts = Vectorizer.transform(X_test)

# %%
# Membuat model regresi logistik
model = SVC (kernel='linear')
model.fit(X_train_counts, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Memprediksi nilai menggunakan model yang telah dilatih
predictions = model.predict(X_test_counts)

# %%
print("evaluasi model :")
print(classification_report(y_test,predictions))

print("\nBerapa hasil prediksi:")
for text,sentiment in zip (X_test,predictions):
    print(f'teks : {text}\nPrediksi_label: {sentiments}\n')

result = pd.DataFrame({'RIVIEW' : X_test,'predicted_label': predictions})
result.to_excel('predictions_svm.xlsx', index=False)

print("Hasil Prediksi Telah Di Ekspor ke 'predictions.xlsx'.")
# Out:
# evaluasi model :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        37
#            1       1.00      0.95      0.97        55
#            2       0.93      1.00      0.97        43
#
#     accuracy                           0.98       135
#    macro avg       0.98      0.98      0.98       135
# weighted avg       0.98      0.98      0.98       135
#
#
# Berapa hasil prediksi:
# teks : jaket tidak milik ventilasi baik sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik bau tidak enak sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat hangat nyaman pakai musim dingin
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat pas tubuh sangat nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak milik ukur pas sangat besar badan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sesuai deskripsi kualitas biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket terlalu berat tidak nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket terlalu tipis tidak hangat sama sekali
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sesuai harga tidak yang tarik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju lumayan nyaman tidak terlalu kesan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat nyaman pakai kendara lindung angin baik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat kasar kulit nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat nyaman pakai mudah cuci
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik bahan sangat lembut nyaman kulit
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah melar kualitas sangat buruk
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik warna tidak mudah pudar meski cuci berkalikali
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju lumayan nyaman tidak terlalu kesan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat tahan lama kuat sangat puas
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik desain sangat tarik sangat puas
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat hangat nyaman pakai musim dingin
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat kualitas bahan guna sangat baik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat ringan tidak panas pakai hari
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak milik ventilasi baik sangat panas pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat ringan nyaman pakai seharihari
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik desain sangat keren sangat suka
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah melar kualitas sangat buruk
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cepat sekali luntur warna kualitas sangat buruk
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sesuai harga tidak yang tarik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat fleksibel tidak batas gera sangat nyaman
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket lumayan nyaman desain biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sesuai deskripsi kualitas biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah melar kualitas sangat buruk
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju tidak sesuai gambar website sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat elegan cocok pakai bagai acara
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat hangat nyaman pakai musim dingin
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik bau tidak enak sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak sesuai ekspektasi sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak tahan lama cepat sekali rusak
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat stylish nyaman pakai hari
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket cepat sekali rusak beberapa kali cuci
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat panas pakai nyaman sama sekali
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cukup nyaman tidak terlalu kesan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat pas tubuh sangat nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju lumayan nyaman tidak terlalu kesan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik kantong baik sangat tidak praktis
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat kualitas bahan guna sangat buruk
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket lumayan nyaman desain biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cukup baik tidak terlalu spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah robek kualitas sangat rendah
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik kualitas sangat bagus sangat rekomendasi
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat hangat nyaman pakai musim dingin
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket lumayan nyaman desain biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju tidak sesuai gambar website sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik warna sangat cantik tidak mudah pudar
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju tidak sesuai ukur tera sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik warna sangat cantik sangat suka
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat kasar kulit nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik desain sangat keren sangat suka
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat kualitas bahan guna sangat baik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sesuai deskripsi kualitas biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat nyaman pakai bahan guna sangat kualitas
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat hangat nyaman pakai musim dingin
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cukup baik tidak terlalu spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket cukup baik tidak yang spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat nyaman pakai mudah cuci
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat tahan lama cepat sekali rusak
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat kasar tidak nyaman kulit
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah robek kualitas sangat rendah
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju lumayan nyaman tidak terlalu kesan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik desain sangat tarik sangat puas
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat nyaman pakai bahan guna sangat buruk
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat hangat nyaman pakai musim dingin
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket cukup baik tidak yang spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cukup baik tidak terlalu spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju terlalu sempit tidak nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat nyaman pakai mudah cuci
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sesuai deskripsi kualitas biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik kualitas sangat bagus sangat rekomendasi
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat panas tidak nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sesuai deskripsi kualitas biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah cuci tidak perlu setrika sangat praktis
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sesuai deskripsi kualitas biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat ringan tidak panas pakai hari
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat elegan cocok pakai bagai acara
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket lumayan nyaman desain biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak tahan air sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak milik ventilasi baik sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju tidak milik kualitas baik sangat mudah rusak
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik desain sangat keren sangat suka
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju lumayan nyaman tidak terlalu kesan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : saya sangat suka baju sangat nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat kualitas bahan guna sangat baik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : saya sangat suka baju sangat nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah padu bagai jenis pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju lumayan nyaman tidak terlalu kesan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat kualitas bahan guna sangat baik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat nyaman pakai mudah cuci
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak milik ukur pas sangat besar badan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah melar kualitas sangat buruk
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat tahan lama cepat sekali rusak
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sesuai deskripsi kualitas biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : saya sangat suka baju sangat nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik resleting cepat rusak sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cukup baik tidak terlalu spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket cukup baik tidak yang spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket cukup baik tidak yang spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket lumayan nyaman desain biasa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik desain sangat tarik sangat puas
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju tidak sesuai gambar website sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : saya suka sekali desain baju sangat trendi
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat kualitas bahan guna sangat baik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak milik ventilasi baik sangat panas pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket tidak tahan air sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket terlalu berat tidak nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cukup baik tidak terlalu spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat pas tubuh sangat nyaman pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju luntur warna sekali cuci sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat mudah sesuai bagai gaya pakai
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju tidak sesuai ukur tera sangat kecewa
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : bahan baju sangat lembut tidak panas pakai hari
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat elegan cocok pakai bagai acara
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cukup baik tidak terlalu spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju sangat elegan cocok pakai bagai acara
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket cukup baik tidak yang spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cukup baik tidak terlalu spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju cepat sekali luntur warna kualitas sangat buruk
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sangat stylish nyaman pakai hari
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik warna sangat cantik tidak mudah pudar
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket cukup baik tidak yang spesial
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sesuai harga tidak yang tarik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik desain sangat keren sangat suka
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket sesuai harga tidak yang tarik
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju lumayan nyaman tidak terlalu kesan
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : baju milik warna sangat cantik tidak mudah pudar
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# teks : jaket milik kualitas sangat bagus sangat rekomendasi
# Prediksi_label: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 445    2
# 446    2
# 447    2
# 448    2
# 449    2
# Name: LABEL, Length: 450, dtype: int64
#
# Hasil Prediksi Telah Di Ekspor ke 'predictions.xlsx'.

# %%
def analyze_text(text) :
    text_counts = Vectorizer.transform([text])
    predictions = model.predict (text_counts)[0]
    return predictions

while True:
    user_input = input ("\nMasukkan Teks Untuk Analisis Sentimen (atau ketik 'exit'untuk keluar :)")
    if user_input.lower()== 'exit':
        break
    sentiment =analyze_text(user_input)
    print(f'Prediksi Sentimen Untuk "{user_input}": {sentiment}')
# Out:
# Prediksi Sentimen Untuk "": 0
# Prediksi Sentimen Untuk "": 0
# Prediksi Sentimen Untuk "": 0
# Prediksi Sentimen Untuk "": 0
# Prediksi Sentimen Untuk "": 0
# Prediksi Sentimen Untuk "": 0
# Prediksi Sentimen Untuk "1": 0
# Prediksi Sentimen Untuk "1": 0
# Prediksi Sentimen Untuk "2": 0
# Prediksi Sentimen Untuk "2": 0
# Prediksi Sentimen Untuk "3": 0
# Prediksi Sentimen Untuk "4": 0
